# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\LSB_09\0I_15\lith'
col = ['Time (s)', 'Potential vs Li$^+$/Li (V)']
files_lith = [os.path.join(path, i) for i in os.listdir(path)]
df = pd.read_csv(files_lith[1], sep = ';', usecols=[1,2], names = col, skiprows=1)
fig, ax = plt.subplots(dpi = 100)
sns.lineplot(data = df, x = col[0], y = col[1])
print(df[col[0]])
# Out:
# 0          0.000000
# 1          1.000000
# 2          2.000000
# 3          3.000000
# 4          4.000000
#            ...
# 3298    3297.999992
# 3299    3298.999992
# 3300    3299.999992
# 3301    3300.999992
# 3302    3301.999992
# Name: Time (s), Length: 3303, dtype: float64

# %%
thickness = 70 # nm
area = 0.63 # cm^2
charge = 2268 * area * 1e-7 * thickness
print(charge/3600) # 1C
# Out:
# 2.7782999999999997e-06
