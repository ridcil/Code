# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lmfit import Model
from scipy.stats import linregress
import seaborn as sns

import powerxrd as xrd

sns.set_theme(style="darkgrid", palette='Set1')

# %%
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\XRD\LSB_11\LMO2h annealed 750 on pls Pt.csv'
cols = ['Angle', 'Intensity']
df = pd.read_csv(path, skiprows = 32, names = cols, usecols=[0,2])
data = np.array([df[cols[0]], df[cols[1]]])
chart = xrd.Chart(*data)
chart.backsub(tol = 1, show = True)
chart.SchPeak(xrange=[18, 20],verbose=True,show=True)


plt.plot(*data, lw = 0.5)
plt.ylim(-300, 5000)
# plt.xlim(17,22)
# plt.show()
# Out:
# -Gaussian fit results-
# y-shift 71.68049133578484
# amplitude 314.89963344221314
# mean 18.69573707433872
# sigma 0.1521468537660733
# covariance matrix
# [[ 5.93459236e+01 -4.80109627e+01 -3.39143875e-07 -1.54636753e-02]
#  [-4.80109627e+01  9.59814586e+01  2.74241988e-07  3.09155513e-02]
#  [-3.39143875e-07  2.74241988e-07  1.77855842e-05  7.19937146e-11]
#  [-1.54636753e-02  3.09155513e-02  7.19937146e-11  2.18149313e-05]]
#
# SchPeak: Scherrer width calc. for peak in range of [18,20]
#
# FWHM == sigma*2*sqrt(2*ln(2)): 0.35827846103674194 degrees
# K (shape factor): 0.9
# K-alpha: 0.15406 nm
# max 2-theta: 18.633752908 degrees
#
# SCHERRER WIDTH: 22.46992596278895 nm
# (-300.0, 5000.0)
