# %%
import tkinter as tk
from tkinter import ttk
from tkinter import filedialog as fd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import pandas as pd
from datetime import datetime
import matplotlib.dates as mdates
import seaborn as sns

matplotlib.use('TkAgg')


class App(tk.Tk):
     
    def __init__(self):
        super().__init__()
    
        # Root window
        self.title('Lesker log')
        self.geometry('800x600')
        
        self.fig = Figure(figsize = (6, 4), dpi = 100)
        self.canvas = FigureCanvasTkAgg(self.fig, master=self)  # A tk.DrawingArea.
        self.canvas.draw()
        self.canvas.get_tk_widget().pack()           #anchor = tk.TOP, expand=True)
        
        # self.canvas = tk.Canvas(self, width=600, height=400, bg = 'gray')
        # self.canvas.pack(anchor=tk.CENTER, expand = True)  
            
        self.btn_openfile = ttk.Button(self, text='Open file')
        self.btn_openfile.bind('<Button-1>', self.plot)
        self.btn_openfile.bind('<Return>', self.plot)
        self.btn_openfile.focus()
        self.btn_openfile.pack(anchor = tk.S)
        
        # self.btn_clear = ttk.Button(self, text = 'Clear')
        # self.btn_clear.bind('<Button-1>', self.clear)
        # self.btn_clear.pack()


    # def open_file(self, event):
    #     filetypes = ( ('Text files', '*.txt'), ('All files', '*.*') )
    #     path = fd.askopenfilename( title='Open a file', initialdir='/', filetypes=filetypes)    

    def plot(self, event):
        
        #Clear screen
        self.canvas.get_tk_widget().destroy()
        
        # open file
        filetypes = ( ('All files', '*.*'), ('Text files', '*.txt') )
        path = fd.askopenfilename( title='Open a file', initialdir='/', filetypes=filetypes)
        # Make plot
        fig = Figure(figsize = (6, 4), dpi = 100)
        ax = fig.add_subplot()
        df = pd.read_csv(path, skiprows = 3)    
        format_string = '%b-%d-%Y %I:%M:%S.%f %p'
        df['Time'] = [datetime.strptime(i, format_string) for i in df['Time Stamp']]
        sns.lineplot(data = df, x = df['Time'], y = 'Power Supply 5 Current', label = 'Current', ax = ax)
        ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
        
        
        self.canvas = FigureCanvasTkAgg(fig, master=self)  # A tk.DrawingArea.
        self.canvas.draw()
        self.canvas.get_tk_widget().pack() # side=tk.TOP, fill=tk.BOTH, 
    
        
        
if __name__ == "__main__":
  app = App()
  app.mainloop()


# App()

# %%
root = tk.Tk()

fig = Figure(figsize = (6, 4), dpi = 100)
ax = fig.add_subplot()

canvas = FigureCanvasTkAgg(fig, master=root)
canvas.draw()
canvas.get_tk_widget().pack()

canvas.get_tk_widget().destroy()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 12
#       8 canvas.get_tk_widget().pack()
#      10 canvas.get_tk_widget().destroy()
# ---> 12 root.mainloop()
#
# File c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py:1485, in Misc.mainloop(self, n)
#    1483 def mainloop(self, n=0):
#    1484     """Call the mainloop of Tk."""
# -> 1485     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
     
    
    
# root = tk.Tk()
# root.title('Lesker log')
# root.geometry('600x400')








# root.mainloop()

######### Useful code for tkinter

# ttk.Label(root, text='Hi, there').pack()
# def select(option):
#     print(option)
# ttk.Button(root, text='Rock', command=lambda: select('Rock')).pack()
# root.attributes('-alpha', 0.5) cool!
 
 
 # self.path = r'C:\Users\lopezb41\OneDrive - imec\Desktop\LSB_09 Annealsys test 2022.12.20-12.19.12.csv'
        # self.format_string = '%b-%d-%Y %I:%M:%S.%f %p'
        # self.fig, self.ax = plt.subplots(facecolor = 'white', dpi = 100)
        # self.lw = 1
        # self.df = pd.read_csv(self.path, skiprows = 3)
        # self.df['Time'] = [datetime.strptime(i, self.format_string) for i in self.df['Time Stamp']]
        # self.ax = sns.lineplot(data = self.df, x = self.df['Time'], y = 'Power Supply 5 Current', lw = self.lw, label = 'Current')
        # self.ax2 = plt.twinx()
        # self.ax2 = sns.lineplot(data = self.df, x = self.df['Time'], y = 'Power Supply 5 Voltage', ax = self.ax2, lw = self.lw, label = 'Voltage', color = 'tab:orange')
        # self.ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
        # self.ax.legend(frameon = False, loc = 2)
        # self.ax2.legend(frameon = False, loc = 1)
