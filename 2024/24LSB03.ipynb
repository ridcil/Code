# %%
#### IMPORT
# %run Methods.ipynb

# %%
### LMO FL 1 constant potential 2.4V
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\Full lithiation\LMO_FL_1'
area = np.pi * (0.5 **2) # cm2
lmo_fl_1 = lsv(path, area, 100)
lmo_fl_1['Sample'].unique()
# Out:
# array(['_LSV_U_LMO_FL_1_2_L_2.4', '_LSV_U_LMO_FL_1_L_2.4'], dtype=object)

# %%
### LMO_N_1 RUN 1
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_1\1'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_1'
lmo_n_1 = cc(path, area, thickness, name)
lmo_n_1[1]['Capacity (mAh/cm$^3$)'].max()
# Out:
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: invalid value encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: invalid value encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1242: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# ...

# %%
### PLOT LMO_N_1 RUN 1
cv_plot(lmo_n_1, color_map, 100)
# color = 'red'
# capacity_cv(lmo_n_1[0], 100, area, 90, 2050, 2910, True)

cc_plot(lmo_n_1, color_map, 100)
# plt.grid()
# dq_dv_plot(lmo_n_1, color_map, 100)
# plt.ylim(-7800, 7800)
# Out:
# 3

# %%
### LMO_N_1 RUN 2
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_1\2'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_2'
# lmo_n_2 = cc(path, area, thickness, name)

lmo_n_2_cr = cc_c_rates(path, area, thickness, name)

lcu = 3.4
ucu = 4.4
# Out:
# window_length must be less than or equal to the size of x.
# window_length must be less than or equal to the size of x.

# %%
### PLOT LMO_N_1 RUN 2
# cv_plot(lmo_n_2_cr, color_map, 100)
# cc_plot(lmo_n_2_cr, color_map, 100)
# plt.ylim(3.4, 4.5)
# plt.grid()

# fig, ax = plt.subplots()
c_rates_plot(lmo_n_2_cr, lcu, ucu, 100)



# dq_dv_plot(lmo_n_2_cr, color_map, 100)
# plt.ylim(-30000, 30000)
# lmo_n_2_cr[2]

# %%
### LMO_N_1 RUN 3 3V region cycling
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_1\3'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_3'
lmo_n_3 = cc(path, area, thickness, name)
lmo_n_3[1]['Capacity (mAh/cm$^3$)'].max()
# Out:
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: invalid value encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: invalid value encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1242: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# ...

# %%
### PLOT LMO_N_1 RUN 3
cv_plot(lmo_n_3, color_map, 100)
cc_plot(lmo_n_3, color_map, 100)
plt.grid()
# capacity_cv(lmo_n_3[0], 100, area, thickness, 2200, 3130, True)
# dq_dv_plot(lmo_n_3, color_map, 100)
# plt.ylim(-50000, 50000)
# Out:
# 2

# %%
### LMO_N_1 RUN 3 3V region cycling LMO N 1 changed channel, got stuck embedded procesor ch1. Sample after cycling 3V region
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_1\4'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_4'
lmo_n_4 = cc(path, area, thickness, name)

# %%
### PLOT LMO_N_1 RUN 4
cv_plot(lmo_n_4, color_map, 100)
#No charge discharge

# capacity_cv(lmo_n_4[0], 100, area, thickness, 500, 3120, True)
# capacity_cv(lmo_n_4[0], 100, area, thickness, 2290, 2750, True)
# capacity_cv(lmo_n_4[0], 100, area, thickness, 3230, 5840, True)
# capacity_cv(lmo_n_4[0], 100, area, thickness, 5150, 5400, True)
# capacity_cv(lmo_n_4[0], 100, area, thickness, 5150, 5840, True)

# %%
### LMO_N_2
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_2\1'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_2'
lmo_n2_1 = cc(path, area, thickness, name)
cv_plot(lmo_n2_1, color_map, 100)

# %%
### LMO_N_2 1.5V
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_2\2'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_2'
lmo_n2_2 = cc(path, area, thickness, name)
cv_plot(lmo_n2_2, color_map, 200)

# cv_scan_plot(lmo_n2_2, 200, 'tab10')

# %%
### LMO_N2_2 after 1V after 4V
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_2\CV after 1_V after 4V'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_2'
lmo_n2_3 = cc(path, area, thickness, name)
# cv_plot(lmo_n2_3, color_map, 100)
cv_scan_plot(lmo_n2_3, 100, 'flare')
# plt.xlim(3.9, 4.1)

# %%
# Formal Potential
# %run Methods.ipynb
res = formal_potential(lmo_n2_3[0], 100, True)
# plt.xlim(4.1, 4.2)
# Out:
# Two peaks in cycle 6 in the 4V region

# %%
# #### 3D Plot
# df = lmo_n2_3[0].sort_values(by = 'Scan', ascending = False)

# # Create 3D plot
# fig = plt.figure(figsize=(8, 6), dpi = 100)
# ax = fig.add_subplot(111, projection='3d')

# # Scatter plot
# ax.scatter(df[col_cv[0]], df['Scan'],  df[strings[0]], c=df['Scan'], s = 2) #, cmap='viridis')


# # Connect points along the y-axis for each z-value
# for scan in df['Scan'].unique():
#     subset = df[df['Scan'] == scan]
#     # ax.plot(subset[col_cv[0]], subset[strings[0]], subset['Scan'], alpha=0.5)

# ax.view_init(elev=5, azim= 85)

# %%
### LMO_N_2 charge discharge 5C
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_2\5'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_2'
lmo_n2_5 = cc(path, area, thickness, name)

# %%
###PLOT LMO_N_2 charge discharge 5C
cc_plot(lmo_n2_5, color_map, 100)
# dq_dv_plot(lmo_n2_5, color_map, 100)
# plt.ylim(-800, 800)
# Out:
# 5

# %%
#### LMO LiPON
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_LiPON\1'
# setup_files(path)
area = 0.7854
thickness = 90
sample = 'LMO/LiPON'
lmo_lipon = cc(path, area, thickness, sample)
# cv_plot(lmo_lipon, color_map, 100)
g = lmo_lipon[0]
fig, ax = plt.subplots(dpi = 200)
# sns.scatterplot(data = g_sort, x = col_cv[0], y = strings[0])
# sns.lineplot(data = g_sort, x = col_cv[0], y = strings[0], sort = False)
ax.plot(g[col_cv[0]], g[strings[0]])
ax.yaxis.set_major_formatter(formatter_1e6)
ax.set_ylabel(strings[1])
ax.set_xlabel(col_cv[0])
ax.grid()

# %%
#### LMO LiPON Charge/Discharge
#### IMPORT
# %run Methods.ipynb

path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_LiPON\2'
# setup_files(path)
area = 0.7854
thickness = 90
sample = 'LMO/LiPON'
lmo_lipon_cd = cc(path, area, thickness, sample)
a = cc_c_rates(path, area, thickness, sample)

b = a[1][a[1]['C-rate'] == 1]
c = a[2][a[2]['C-rate'] == 1]
# Out:
# window_length must be less than or equal to the size of x.
# window_length must be less than or equal to the size of x.
# window_length must be less than or equal to the size of x.
# window_length must be less than or equal to the size of x.
# window_length must be less than or equal to the size of x.
# window_length must be less than or equal to the size of x.
# window_length must be less than or equal to the size of x.
# window_length must be less than or equal to the size of x.
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# ...

# %%
#Plots LMO LiPON C/D
# cv_plot(lmo_lipon_cd, color_map, 100)
# cc_plot(a, color_map, 100)
# dq_dv_plot(lmo_lipon_cd, color_map, 100)
# plt.ylim(-3000, 3000)
c_rates_plot(a, 3.4, 4.5, 100)
d = pd.concat([b,c], ignore_index=True)

### dQ/dV plot
fig, ax = plt.subplots(dpi = 200)
# sns.scatterplot(data = d, x = 'WE(1).Potential (V)', y = 'dQ/dV', hue = 'Process', edgecolor = None, s = 2)
sns.scatterplot(data = d, x = 'Capacity (mAh/cm$^3$)', y = 'WE(1).Potential (V)', hue = 'Process', edgecolor = None, s = 2)
plt.ylabel(col_cv[0])
plt.grid()

# %%
# capacity_crates = pd.concat
# lmo_n_2_cr
# lmo_lipon_cd

a = c_rate_capacity(lmo_n_2_cr, 3.4, 4.5)
b = c_rate_capacity(lmo_lipon_cd, 3.4, 4.5)
c = pd.concat([a,b], ignore_index=True)

fig, ax = plt.subplots(dpi = 100)
sns.scatterplot(data = c, x = 'C-rate', y = 'Capacity (mAh/cm$^3$)', hue = 'Sample', style='Sample', s = 50,legend = False)
sns.lineplot(data = c, x = 'C-rate', y = 'Capacity (mAh/cm$^3$)', hue = 'Sample', style = 'Process' )
ax.set_xscale('log')
plt.grid()

# %%
# PLOT 1C rate
# fig, ax = plt.subplots(dpi = 200)
# sns. lineplot(data = d, x = 'Capacity (mAh/cm$^3$)', y = 'WE(1).Potential (V)', hue = 'Process')
# ax.set_ylabel(col_cv[0])
# ax.grid()
