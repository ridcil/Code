# %%
#### IMPORT
# %run Methods.ipynb

# %%
### LMO FL 1
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\Full lithiation\LMO_FL_1'
area = np.pi * (0.5 **2) # cm2
lmo_fl_1 = lsv(path, area, 100)
lmo_fl_1['Sample'].unique()
# Out:
# array(['_LSV_U_LMO_FL_1_2_L_2.4', '_LSV_U_LMO_FL_1_L_2.4'], dtype=object)

# %%
### LMO_N_1 RUN 1
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_1\1'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_1'
lmo_n_1 = cc(path, area, thickness, name)
lmo_n_1[1]['Capacity (mAh/cm$^3$)'].max()
# Out:
# 460.9389159829541

# %%
### PLOT LMO_N_1 RUN 1
cv_plot(lmo_n_1, color_map, 200)
color = 'red'
# capacity_cv(lmo_n_1[0], 100, area, 90, 2050, 2910, True)

cc_plot(lmo_n_1, color_map, 200)
plt.grid()
# dq_dv_plot(lmo_n_1, color_map, 100)
# plt.ylim(-7800, 7800)

# %%
### LMO_N_1 RUN 2
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_1\2'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_2'
# lmo_n_2 = cc(path, area, thickness, name)

lmo_n_2_cr = cc_c_rates(path, area, thickness, name)

lcu = 3.4
ucu = 4.4
# Out:
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1242: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1248: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# ...

# %%
### PLOT LMO_N_1 RUN 2
cv_plot(lmo_n_2_cr, color_map, 100)
cc_plot(lmo_n_2_cr, color_map, 100)

fig, ax = plt.subplots()
c_rates_plot(lmo_n_2_cr, lcu, ucu)

# dq_dv_plot(lmo_n_2_cr, color_map, 100)
# plt.ylim(-30000, 30000)

# %%
### LMO_N_1 RUN 3 3V region cycling
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_1\3'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_3'
lmo_n_3 = cc(path, area, thickness, name)
lmo_n_3[1]['Capacity (mAh/cm$^3$)'].max()
# Out:
# 377.2010617329266

# %%
### PLOT LMO_N_1 RUN 3
cv_plot(lmo_n_3, color_map, 200)
cc_plot(lmo_n_3, color_map, 200)
plt.grid()
# capacity_cv(lmo_n_3[0], 100, area, thickness, 2200, 3130, True)
# dq_dv_plot(lmo_n_3, color_map, 100)
# plt.ylim(-50000, 50000)

# %%
### LMO_N_1 RUN 3 3V region cycling LMO N 1 changed channel, got stuck embedded procesor ch1. Sample after cycling 3V region
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_1\4'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_4'
lmo_n_4 = cc(path, area, thickness, name)

# %%
### PLOT LMO_N_1 RUN 4
cv_plot(lmo_n_4, color_map, 100)
#No charge discharge

# capacity_cv(lmo_n_4[0], 100, area, thickness, 500, 3120, True)
# capacity_cv(lmo_n_4[0], 100, area, thickness, 2290, 2750, True)
# capacity_cv(lmo_n_4[0], 100, area, thickness, 3230, 5840, True)
# capacity_cv(lmo_n_4[0], 100, area, thickness, 5150, 5400, True)
# capacity_cv(lmo_n_4[0], 100, area, thickness, 5150, 5840, True)

# %%
### LMO_N_2
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_2\1'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_2'
lmo_n2_1 = cc(path, area, thickness, name)
cv_plot(lmo_n2_1, color_map, 100)

# %%
### LMO_N_2 1.5V
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_2\2'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_2'
lmo_n2_2 = cc(path, area, thickness, name)
cv_plot(lmo_n2_2, color_map, 100)

cv_scan_plot(lmo_n2_2, 200, 'tab10')
