# %%
# Import methods

# %run Methods.ipynb

# %% [markdown]
# MARCH

# %% [markdown]
# LMO FL 2.4V Deposition Transient NanoSCE mimic

# %%
### LMO Full lithiation at 2.4V
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\LMO_FL'
lmo_fl_1, samples = sce_dep2(path)
#### PLOT LMO Full lithiation at 2.4V
dep_plot(lmo_fl_1, [0], True, 100)
# lmo_fl_1

# %% [markdown]
# Plot dQ/dV vs V of deposition during the first 20 seconds

# %%
# dQ/dV of deposition
a = lmo_fl_1[lmo_fl_1['Corrected time (s)'] < 20]
# z = a[a['Corrected time (s)'] < 15]
x = a['Corrected time (s)']
y = a['WE(1).Potential (V)']

k = a['WE(1).Charge (C)']

x_ = savgol_filter(x, 15, 2)
y_ = savgol_filter(y, 15, 2)
# plt.plot(x, k)
# plt.show()

plt.plot(x, y)
plt.plot(x_, y_)
plt.show()

grad = savgol_filter(np.gradient(x, y), 5, 1)

plt.plot(y, grad)
plt.grid()
# Out:
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: invalid value encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: invalid value encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1242: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# ...

# %% [markdown]
# LMO Overlithiation 1.5V

# %%
# LMO OverLithiation at 1.5V
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\LMO_OL'
lmo_ol_1, s = sce_dep2(path)
#### PLOT LMO OverLithiation at 1.5V
dep_plot(lmo_ol_1, [0], False, 100)

# %% [markdown]
# LMO Normal - as prepared -

# %%
# LMO Normal
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\LMO_N'
lmo_n, s = sce_dep2(path)
#### PLOT LMO Normal
dep_plot(lmo_n, [0], True, 100)

# %% [markdown]
# Cyclic Voltametry of  LMO in mimic solution 1mV/s, using RDE holder, static. Between

# %%
### LMO_N_w1 CV in water 1mV/s
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\LMO CV'
area = (0.75 **2) * np.pi
sample = 'LMO in water 1'
lmo_cv_water = cv_water(path, area, 100, 'tab10')

# %% [markdown]
# LMO Normal scanned in mimic solution using Teflon cell area = 0.7854 cm2, 1mV/s between 3.4 and 4.4 V vs Li/Li. 0.3 and 1.2 V vs AgCl/Ag. New sample

# %%
### LMO_N_w2 CV in water 1mV/s RUN 2 short window
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\LMO_CV_2\LMOcycling'
area = (0.5 **2) * np.pi
thickness = 90
sample = 'LMO in water 2'
lmo_cv_water_2_s = cv_water(path, area, 100, 'tab10')

# %% [markdown]
# LMO_N_w2 in mimic solution 1mV/s teflon cell. Same sample from before. Scanned between -1 to 1.2 V vs AgCl/Ag. This sample shows the peak that appears after going to low potentials (1.5 vs Li+/Li) in PC

# %%
### LMO N CV in water 1mV/s RUN 2
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\LMO_CV_2\LMO CV -1V to 1.2V'
area = (0.5 **2) * np.pi
sample = 'LMO in water 2'
lmo_cv_water_2 = cv_water(path, area, 100, 'tab10')

# %% [markdown]
# Comparison between LMO in PC and LMO in water, wide potential range

# %%
# New LMO cv low potentials 1.5V in PC
# path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB01\STD_CV'
# setup_files(path)
# area = np.pi
# thickness = 90
# sample = 'LMO in PC'
# std02_lp = cc(path, area, thickness, sample)

### LMO_N_1 RUN 3 3V region cycling LMO N 1 changed channel, got stuck embedded procesor ch1. Sample after cycling 3V region
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24LSB03\LMO_N_1\4'
area = np.pi * (0.5 **2) # cm2
thickness = 90
setup_files(path)
name = 'LMO_N_4'
lmo_n_4 = cc(path, area, thickness, name)

b = lmo_n_4[0][lmo_n_4[0]['Scan'] != 1] # LMO in PC

q = lmo_cv_water[lmo_cv_water['Scan'] == 1] # LMO in water
q2 = lmo_cv_water_2[lmo_cv_water_2['Scan'] != 1]
fig, ax = plt.subplots(dpi = 200)

sns.scatterplot(data = q2, x = col_cv[0], y = strings[0], edgecolor = None, s = 3, label = 'LMO in Water')
sns.scatterplot(data = b, x = col_cv[0], y = strings[0], edgecolor = None, s = 3, label = 'LMO in PC')
ax.yaxis.set_major_formatter(formatter_1e6)
plt.ylabel(strings[1])
plt.grid()

# %% [markdown]
# Chronopotentiometry of LMO lithiated in mimic solution. The sample was held at -0.6 V vs AgCl/Ag

# %%
### LMO Fully lithiated in water
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\LMO_FL in water'
lmo_wfl, s = sce_dep(path)
#### PLOT LMO Fully lithiated in water
dep_plot(lmo_wfl, [0], True, 100)

# %% [markdown]
# Chronopotentiometry Pt with 9nm ALD TiO2 in mimic solution. You can see here that the potential drops more that with Pt alone, water reduction is shifter ~100mV

# %%
### Pt TiO2 9 nm
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\Pt_TiO2'
pt_tio2_water, s = sce_dep2(path)
#### PLOT PT tiO2
dep_plot(pt_tio2_water, [0], True, 100)

# %%
#### LMO cycled in water
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\LMOcycling in water'
files = [os.path.join(path, i) for i in os.listdir(path)]
cv = [i for i in files if 'CV' in i]
delith = [i for i in files if 'Delith' in i]
lith = [ i for i in files if 'Lith' in i]

df_cv = pd.read_csv(cv[0], sep = ';')

# cd = pd.DataFrame()
# for i in delith:
#     df = pd.read_csv(i, sep = ';')
#     df['Process'] = 'Delith'
#     df['Cycle'] = os.path.basename(i)[:-4]
#     cd = pd.concat([cd, df], ignore_index=True)
# cd
fig, ax = plt.subplots()
sns.scatterplot(data = df_cv, x = 'WE(1).Potential (V)', y =  'WE(1).Current (A)', edgecolor = None, s = 2)

# fig, ax = plt.subplots()
# sns.lineplot(data = cd, x = 'Corrected time (s)', y = 'WE(1).Current (A)', hue = 'Cycle')
# Out:
# <AxesSubplot: xlabel='WE(1).Potential (V)', ylabel='WE(1).Current (A)'>

# %%
#### Compare samples MARCH
z = pd.concat([lmo_fl_1, lmo_ol_1, lmo_wfl, lmo_n, pt_tio2_water], ignore_index=True)
samples = pd.DataFrame(z['Sample'].unique())
sample_list = [0,2,3,4]#, 13]
dep_plot(z, sample_list, True, 100)
samples
# Out:
#                          0
# 0                 LMO_FL_1
# 1                 LMO_OL_1
# 2  LMO_FL in water galvdep
# 3                  LMO_N_1
# 4                Pt_TiO2_1

# %%
#### NanoSCE grow in Pt FEB
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Feb_NanoSCE\19FEB'
pt_sce, samples = sce_dep(path)
sample_list = [ 6]
dep_plot(pt_sce, sample_list, True, 100)
samples
# Out:
#        Samples
# 0     LMOSTD_1
# 1     LMOSTD_2
# 2    Pt10LMO_1
# 3    Pt10LMO_2
# 4   PtITOLMO_1
# 5   PtITOLMO_2
# 6         Pt_1
# 7         Pt_2
# 8         Pt_3
# 9        TiN_1
# 10       TiN_2
# 11       TiN_3

# %%
### NanoSCE deposition March7th
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\March7th\LMOFL2'
lmofl2, s = sce_dep(path)
dep_plot(lmofl2, [0], False, 200)

# %%
######################################################
a = pd.concat([pt_sce, lmofl2], ignore_index=True)
samples = pd.DataFrame(a['Sample'].unique())
display(samples)
s_list = [6, 12]

dep_plot(a, s_list, True, 100)
dep_plot(a, s_list, False, 200)
# Out:
#                0
# 0       LMOSTD_1
# 1       LMOSTD_2
# 2      Pt10LMO_1
# 3      Pt10LMO_2
# 4     PtITOLMO_1
# 5     PtITOLMO_2
# 6           Pt_1
# 7           Pt_2
# 8           Pt_3
# 9          TiN_1
# 10         TiN_2
# 11         TiN_3
# 12  LMO_FL_2_SCE

# %% [markdown]
# Integrate charge from chronopotentiometry and CV in water

# %%
lmo_w = lmo_cv_water[lmo_cv_water['Scan'] == 2]
area = (0.75 **2) * np.pi
thicknss = 90
# cv_plot(lmo_w, color_map, 100 )
ci = 400
cf = 1000
color = 'red'
# charge_cv(lmo_w, 100, ci, cf, True)
capacity_cv(lmo_w, 100, area, thickness, ci, cf, True)

# lmo_fl_dep = lmo_fl_1[lmo_fl_1['Corrected time (s)'] < 1.7]
# dep_plot(lmo_fl_dep, [0], True, 100)


# fig, ax = plt.subplots()
# sns.lineplot(data = lmo_fl_dep, x = 'Corrected time (s)', y ='WE(1).Charge (C)')
# lmo_fl_dep

charge = -0.001332	# C

# %% [markdown]
# LMO charge discharge #1 in water

# %%
#LMO water 1

path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\LMOcycling in water\2'
# setup_files(path)
area = 0.7854 #cm2
thickness = 90 # nm
sample = 'LMO water 1'
lmow_1 = cc(path, area, thickness, sample)
# Out:
# Column Corrected Time has a problem
# Column Corrected Time has a problem
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1240: RuntimeWarning: invalid value encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\lopezb41\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning: invalid value encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# ...

# %%
###Plots
cc_plot(lmow_1, 'BuPu', 200)
plt.ylabel('Potential vs AgCl/Ag (V)')
plt.xlim(-50, 800)
dq_dv_plot(lmow_1, color_map, 200)
plt.ylim(-0.7e4, 0.5e4)
plt.xlabel('Potential vs AgCl/Ag (V)')
# len(lmow_1[1])
# Out:
# 5
# Text(0.5, 0, 'Potential vs AgCl/Ag (V)')

# %% [markdown]
# 19March SCE dep

# %%
#19MARC SCE deposition

path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\24MarNanoSCE_2'

df, s = sce_dep(path)
show = [0, 6]
dep_plot(df, show, True, 100)
s
# Out:
#       Samples
# 0   LMO_FL_21
# 1   LMO_FL_22
# 2   LMO_FL_23
# 3  LMO_FL_233
# 4        Pt_1
# 5        Pt_2
# 6       TiN_1
# 7       TiN_2

# %% [markdown]
# SCE depositions on 22nd March. Tested several TiN and LMO. First attempt with pulses

# %%
# 22MAR SCE deposition with BMP
# %run Methods.ipynb
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Mar_NanoSCE\22mar'

dep_22mar, s_22mar = sce_dep(path)
pp = pd.DataFrame(columns=[f'Peak {col_dep[0]}', 'Pulse #', 'Sample'])
# dep_22mar
# s_22mar

# %%
x = s_22mar['Samples']

n = 0
m = 1
for index, value in x.items():
    # try:
    sample = x[index]        
    try:
        check = len(x[index + 1])
    except KeyError:
        pass
    
    w = dep_22mar[dep_22mar['Sample'] == value]
    peak_potential = w['WE(1).Potential (V)'].min()
    pp.loc[n] = (peak_potential, int(m), value[:-3])
    m += 1
    n += 1
    
    if check != len(sample):
        print(f'change {m}')
        m = 1
        continue

e = pp[pp['Sample'] == 'LMO_N_00'] 
p = pp[pp['Sample'] == 'LMO_N_04']
ni = pp[pp['Sample'] == 'TiN_04']
# qq = pp[pp['Sample'] == 'LMO_N']
t = pd.concat([e, p, ni])

fig, ax = plt.subplots(dpi = 200)
sns.lineplot(data = t, x = 'Pulse #', y = f'Peak {col_dep[0]}', hue = 'Sample', style = 'Sample', markers = True)
# # s_22mar

#LMO series2 LMO_N_04
show4 = np.arange(12, 22)
dep_plot(dep_22mar, show4, False, 200)


# # #LMO series1
# show3 = np.arange(0, 10)
# dep_plot(dep_22mar, show3, True, 100)

# # #lmo
# show = [10,11]
# dep_plot(dep_22mar, show, True, 100)

# #TiN
show2 = np.arange(25, 35)
dep_plot(dep_22mar, show2, False, 200)

# s_22mar
# Out:
# change 11
# change 3
# change 11
# change 4

# %%
### make derivative of transient dt/dV

# dep_22mar
a = dep_22mar[dep_22mar['Sample'] == s_22mar.loc[12][0]]
n = 51
x = a['Corrected time (s)']
y = a['WE(1).Potential (V)']

g = deriv_x_y(x, y, 51, 1, 111, 1, True)

# Plot
# fig, ax = plt.subplots(dpi = 100)
# plt.plot(x,y, label = 'Raw Data')
# plt.plot(x_,y_, label = 'Smooth Data')
# plt.legend()
# plt.plot(y, g[2])
plt.xlabel('Potential vs AgCl/Ag (V)')
plt.ylabel('dt/dV')
# plt.plot(y,g)
# a8
# Out:
# Text(0, 0.5, 'dt/dV')

# %%
fig, ax = plt.subplots(dpi = 100)
for i in s_22mar['Samples']:
    if 'TiN' in i:

        a = dep_22mar[dep_22mar['Sample'] == i]
        n = 61
        x = a['Corrected time (s)']
        y = a['WE(1).Potential (V)']
        x_ = savgol_filter(a['Corrected time (s)'], n, 1)
        y_ = savgol_filter(a['WE(1).Potential (V)'], n, 1)
        grad = savgol_filter(np.gradient(x_, y_), 111, 1)
            
        # Plot
        # fig, ax = plt.subplots(dpi = 100)
        # plt.plot(x,y, label = 'Raw Data')
        # plt.plot(x_,y_, label = 'Smooth Data')
        # fig, ax = plt.subplots(dpi = 100)
        plt.plot(y, grad, label = i)
        plt.xlabel('Potential vs AgCl/Ag (V)')
        plt.ylabel('dt/dV')
        plt.ylim(-400, 10)
        plt.xlim(-2.1, -1)
        plt.legend()

# %%
a = df[df['Sample'] == 'LMO_FL_21']
x = -a['WE(1).Charge (C)']
y = a['WE(1).Potential (V)']
x_ = savgol_filter(x, 111, 1)
y_ = savgol_filter(y, 111, 1)
a['dQ/dV'] = savgol_filter(np.gradient(x_, y_), 111, 1)

plt.plot(x, y)
plt.plot(x_, y_)
fig, ax = plt.subplots()
sns.scatterplot(data = a, x = 'WE(1).Potential (V)', y = 'dQ/dV', edgecolor = None, s = 5) 
plt.grid()


g = deriv_x_y(x, y , 111, 1, 111, 1, True)
fig, ax = plt.subplots()
plt.plot(y, g)
# Out:
# C:\Users\lopezb41\AppData\Local\Temp\ipykernel_18408\4041736208.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['dQ/dV'] = savgol_filter(np.gradient(x_, y_), 111, 1)

# %% [markdown]
# FEB

# %%
### Deposition NanoSCE FEB
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\24Feb_NanoSCE\19FEB'
df, samples = sce_dep(path)

# %% [markdown]
# COMPARISON and PLOT

# %%
#### Compare samples
z = pd.concat([df, lmo_fl_1, lmo_ol_1, lmo_n, lmo_wfl], ignore_index=True)
samples = pd.DataFrame(z['Sample'].unique())
sample_list = [12, 14, 15, 9]#, 13]
dep_plot(z, sample_list, True, 100)
dep_plot(z, sample_list, False, 200)
samples
# Out:
#                           0
# 0                  LMOSTD_1
# 1                  LMOSTD_2
# 2                 Pt10LMO_1
# 3                 Pt10LMO_2
# 4                PtITOLMO_1
# 5                PtITOLMO_2
# 6                      Pt_1
# 7                      Pt_2
# 8                      Pt_3
# 9                     TiN_1
# 10                    TiN_2
# 11                    TiN_3
# 12                 LMO_FL_1
# 13                 LMO_OL_1
# 14                  LMO_N_1
# 15  LMO_FL in water galvdep
