# %%
#### IMPORT
# %run Methods.ipynb

# %%
###LMNO
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\2024\LMNO_Joan\CV\1'
setup_files(path)
sample = 'LMNO'
area = 0.7854
thickness = 90
lmno_j = cc(path, area, thickness, sample)

cv_plot(lmno_j, 'tab10', 200)
plt.legend().remove()
