# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from preannealing_pt import Ec

# %%
# =============================== LMOref NA Pt ==============================================================================================
path_ref = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\LSB_09\0I_20'
sample = 'LMOref not annealed Pt 0I_20'
df_cv_lmo_ref_na, capacity_lmo_ref_na, lith_lmo_ref_na, delith_lmo_ref_na, efficiency_lmo_ref_na = Ec.Electrochem(path_ref, 90, 0.785, sample)
data = [df_cv_lmo_ref_na, capacity_lmo_ref_na, lith_lmo_ref_na, delith_lmo_ref_na]
for i in data:
    i['Sample'] = sample


fig, ax = plt.subplots(1, 4, dpi = 100, figsize = (25, 5))
# ax2 = ax[2].twinx()
sns.scatterplot(data = df_cv_lmo_ref_na, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'CV', ax = ax[0], edgecolor = None, s = 3)
sns.lineplot(data = lith_lmo_ref_na, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu')
sns.lineplot(data = delith_lmo_ref_na, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
# ax[1].legend(frameon=False)
sns.scatterplot(data = efficiency_lmo_ref_na[1:], x = 'Cycle' , y = 'Efficiency (%)', ax = ax[3],  c = 'tab:red', s = 100)
sns.scatterplot(data = capacity_lmo_ref_na[1:], x = 'Cycle', y = 'Capacity (mAh/cm$^3$)', hue = 'Charge/Discharge', style = 'Charge/Discharge', ax = ax[2], legend = True, markers = ['s', '^' ], s = 100)
# ax[2].legend(['Efficiency'], loc = 10, frameon = False)
# ax2.legend(frameon = False, loc = 7)
plt.suptitle(sample)
# Out:
# Text(0.5, 0.98, 'LMOref not annealed Pt 0I_20')

# %%
path_ref = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\Preannealing\Annealed Pt\01\\CC1'
sample = 'LMO Annealed Pt 1 CC1'
df_cv_lmo_a1, capacity_lmo_a1, lith_lmo_a1, delith_lmo_a1, efficiency_lmo_a1 = Ec.Electrochem(path_ref, 90, 0.785, sample)
data = [df_cv_lmo_a1, capacity_lmo_a1, lith_lmo_a1, delith_lmo_a1]
for i in data:
    i['Sample'] = sample


fig, ax = plt.subplots(1, 4, dpi = 100, figsize = (25, 5))
# ax2 = ax[2].twinx()
sns.scatterplot(data = df_cv_lmo_a1, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'CV', ax = ax[0], edgecolor = None, s = 3)
sns.lineplot(data = lith_lmo_a1, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu')
sns.lineplot(data = delith_lmo_a1, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
ax[1].legend(frameon=False)
sns.scatterplot(data = efficiency_lmo_a1[1:], x = 'Cycle' , y = 'Efficiency (%)', ax = ax[3],  c = 'tab:red', s = 200)

sns.scatterplot(data = capacity_lmo_a1[1:], x = 'Cycle', y = 'Capacity (mAh/cm$^3$)', hue = 'Charge/Discharge', style = 'Charge/Discharge', ax = ax[2], legend = True, markers = ['s', '^' ], s = 100)
# ax[2].legend(bbox_to_anchor=(0.8, 1.1), frameon = False)
# ax2.legend(frameon = False, bbox_to_anchor=(0.5, 1.1), ncols = 2)
plt.suptitle(sample)
# Out:
# Text(0.5, 0.98, 'LMO Annealed Pt 1 CC1')

# %%
path_ref = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\Preannealing\Annealed Pt\01\\CC2'
sample = 'LMO Annealed Pt 1 CC2'
df_cv_lmo_a1_2, capacity_lmo_a1_2, lith_lmo_a1_2, delith_lmo_a1_2, efficiency_lmo_a1_2 = Ec.Electrochem(path_ref, 90, 0.785, sample)
data = [df_cv_lmo_a1_2, capacity_lmo_a1_2, lith_lmo_a1_2, delith_lmo_a1_2]
for i in data:
    i['Sample'] = sample

fig, ax = plt.subplots(1, 4, dpi = 100, figsize = (25, 5))
# ax2 = ax[2].twinx()
sns.scatterplot(data = df_cv_lmo_a1_2, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'CV', ax = ax[0], edgecolor = None, s = 3)
sns.lineplot(data = lith_lmo_a1_2, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu')
sns.lineplot(data = delith_lmo_a1_2, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
ax[1].legend(frameon=False)
sns.scatterplot(data = efficiency_lmo_a1_2[1:], x = 'Cycle' , y = 'Efficiency (%)', ax = ax[3],  c = 'tab:red', s = 200, label = 'Efficiency')

sns.scatterplot(data = capacity_lmo_a1_2[1:], x = 'Cycle', y = 'Capacity (mAh/cm$^3$)', hue = 'Charge/Discharge', style = 'Charge/Discharge', ax = ax[2], legend = True, markers = ['s', '^' ], s = 100)
# ax[2].legend(bbox_to_anchor=(0.8, 1.1), frameon = False)
# ax2.legend(frameon = False, bbox_to_anchor=(0.5, 1.1), ncols = 2)
plt.suptitle(sample)
# Out:
# Text(0.5, 0.98, 'LMO Annealed Pt 1 CC2')

# %%
path_ref = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\Preannealing\Annealed Pt\01\\CC3'
sample = 'LMO Annealed Pt 1 CC3'
df_cv_lmo_a1_3, capacity_lmo_a1_3, lith_lmo_a1_3, delith_lmo_a1_3, efficiency_lmo_a1_3 = Ec.Electrochem(path_ref, 90, 0.785, sample)
data = [df_cv_lmo_a1_3, capacity_lmo_a1_3, lith_lmo_a1_3, delith_lmo_a1_3]
for i in data:
    i['Sample'] = sample

fig, ax = plt.subplots(1, 4, dpi = 100, figsize = (25, 5))
# ax2 = ax[2].twinx()
sns.scatterplot(data = df_cv_lmo_a1_3, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'CV', ax = ax[0], edgecolor = None, s = 3)
sns.lineplot(data = lith_lmo_a1_3, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu')
sns.lineplot(data = delith_lmo_a1_3, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
ax[1].legend(frameon=False)
sns.scatterplot(data = efficiency_lmo_a1_3[1:], x = 'Cycle' , y = 'Efficiency (%)', ax = ax[3],  c = 'tab:red', s = 200, label = 'Efficiency')

sns.scatterplot(data = capacity_lmo_a1_3[1:], x = 'Cycle', y = 'Capacity (mAh/cm$^3$)', hue = 'Charge/Discharge', style = 'Charge/Discharge', ax = ax[2], legend = True, markers = ['s', '^' ], s = 100)
# ax[2].legend(bbox_to_anchor=(0.8, 1.1), frameon = False)
# ax2.legend(frameon = False, bbox_to_anchor=(0.5, 1.1), ncols = 2)
plt.suptitle(sample)
# Out:
# Text(0.5, 0.98, 'LMO Annealed Pt 1 CC3')

# %%
sample = 'LMO Annealed Pt 1'

df_charge= pd.concat([capacity_lmo_a1[capacity_lmo_a1['Charge/Discharge'] == 'Charge'], capacity_lmo_a1_2[capacity_lmo_a1['Charge/Discharge'] == 'Charge'], capacity_lmo_a1_3[capacity_lmo_a1['Charge/Discharge'] == 'Charge']])
df_charge['Cycle'] = np.arange(len(df_charge)) + 1
df_discharge= pd.concat([capacity_lmo_a1[capacity_lmo_a1['Charge/Discharge'] == 'Discharge'], capacity_lmo_a1_2[capacity_lmo_a1['Charge/Discharge'] == 'Discharge'], capacity_lmo_a1_3[capacity_lmo_a1['Charge/Discharge'] == 'Discharge']])
df_discharge['Cycle'] = np.arange(len(df_discharge)) + 1
df = pd.concat([df_charge, df_discharge], ignore_index=True)

ef2 = efficiency_lmo_a1_2.copy()
ef3 = efficiency_lmo_a1_3.copy()
ef2['Cycle'] = efficiency_lmo_a1_2['Cycle'] + 5
ef3['Cycle'] = efficiency_lmo_a1_3['Cycle'] + 10
eff = pd.concat([efficiency_lmo_a1, ef2, ef3])
eff['Sample'] = sample

lla2 = lith_lmo_a1_2.copy()
lla3 = lith_lmo_a1_3.copy()
dla2 = delith_lmo_a1_2.copy()
dla3 = delith_lmo_a1_3.copy()
lla2['Cycle'] = lith_lmo_a1_2['Cycle'] + 5
lla3['Cycle'] = lith_lmo_a1_3['Cycle'] + 10
dla2['Cycle'] = delith_lmo_a1_2['Cycle'] + 5
dla3['Cycle'] = delith_lmo_a1_3['Cycle'] + 10

l = pd.concat([lith_lmo_a1, lla2, lla3], ignore_index=True)
d = pd.concat([delith_lmo_a1, dla2, dla3], ignore_index=True)
l['Sample'] = sample
d['Sample'] = sample

# ================== PLOT ========================================

fig, ax = plt.subplots( 2, 2, dpi = 200, figsize = (12,10))
sns.scatterplot(data = df_cv_lmo_a1_3, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'CV', ax = ax[0,0], edgecolor = None, s = 3, palette = 'BuPu')
sns.scatterplot(data = df, x = 'Cycle', y = 'Capacity (mAh/cm$^3$)', hue = 'Charge/Discharge', style = 'Charge/Discharge', legend = True, markers = ['s', '^' ], s = 200, palette = 'BuPu', ax = ax[1,0])
ax[1,0].set_ylim(500, 600)
sns.lineplot(data = l, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', hue = 'Cycle', palette = 'BuPu', legend = False, ax = ax[0,1])
sns.lineplot(data = d, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', hue = 'Cycle', palette = 'BuPu', legend = False, ax = ax[0,1])
sns.scatterplot(data = eff, x = 'Cycle', y = 'Efficiency (%)', s = 150,  ax = ax[1,1], c = 'tab:purple')
# ax[2].set_title('Efficiency')
ax[1,1].set_ylim(90,100)
plt.suptitle(sample)
# Out:
# Text(0.5, 0.98, 'LMO Annealed Pt 1')

# %%
# ==================== NA Pt CC1=========================
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\Preannealing\Annealed Pt\02\CC1'
sample = 'LMO Non-Annealed Pt CC1'
df_cv_lmo_na, capacity_lmo_na, lith_lmo_na, delith_lmo_na, efficiency_lmo_na = Ec.Electrochem(path, 90, 0.785, sample)
data = [df_cv_lmo_na, capacity_lmo_na, lith_lmo_na, delith_lmo_na]
for i in data:
    i['Sample'] = sample

fig, ax = plt.subplots(1, 4, dpi = 100, figsize = (25, 5))
# ax2 = ax[2].twinx()
sns.scatterplot(data = df_cv_lmo_na, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'CV', ax = ax[0], edgecolor = None, s = 3)
sns.lineplot(data = lith_lmo_na, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
sns.lineplot(data = delith_lmo_na, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
ax[1].legend(frameon=False)
sns.scatterplot(data = efficiency_lmo_na[1:], x = 'Cycle' , y = 'Efficiency (%)', ax = ax[3],  c = 'tab:red', s = 200, label = 'Efficiency')

sns.scatterplot(data = capacity_lmo_na[1:], x = 'Cycle', y = 'Capacity (mAh/cm$^3$)', hue = 'Charge/Discharge', style = 'Charge/Discharge', ax = ax[2], legend = True, markers = ['s', '^' ], s = 100)
# ax[2].legend(bbox_to_anchor=(0.8, 1.1), frameon = False)
# ax2.legend(frameon = False, bbox_to_anchor=(0.5, 1.1), ncols = 2)
plt.suptitle(sample)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0.98, 'LMO Non-Annealed Pt CC1')

# %%
# ==================== NA Pt CC2=========================
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\Preannealing\Annealed Pt\02\CC2'
sample = 'LMO Non-Annealed Pt CC2'
df_cv_lmo_na2, capacity_lmo_na2, lith_lmo_na2, delith_lmo_na2, efficiency_lmo_na2 = Ec.Electrochem(path, 90, 0.785, sample)
data = [df_cv_lmo_na2, capacity_lmo_na2, lith_lmo_na2, delith_lmo_na2]
for i in data:
    i['Sample'] = sample

fig, ax = plt.subplots(1, 4, dpi = 100, figsize = (25, 5))
# ax2 = ax[2].twinx()
# sns.scatterplot(data = df_cv_lmo_na2, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'CV', ax = ax[0], edgecolor = None, s = 3)
sns.lineplot(data = lith_lmo_na2, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
sns.lineplot(data = delith_lmo_na2, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
ax[1].legend(frameon=False)
sns.scatterplot(data = efficiency_lmo_na2[1:], x = 'Cycle' , y = 'Efficiency (%)', ax = ax[3],  c = 'tab:red', s = 200, label = 'Efficiency')

sns.scatterplot(data = capacity_lmo_na2[1:], x = 'Cycle', y = 'Capacity (mAh/cm$^3$)', hue = 'Charge/Discharge', style = 'Charge/Discharge', ax = ax[2], legend = True, markers = ['s', '^' ], s = 100)
# ax[2].legend(bbox_to_anchor=(0.8, 1.1), frameon = False)
# ax2.legend(frameon = False, bbox_to_anchor=(0.5, 1.1), ncols = 2)
plt.suptitle(sample)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0.98, 'LMO Non-Annealed Pt CC2')

# %%
# ==================== NA Pt CC3=========================
path = r'C:\Users\lopezb41\OneDrive - imec\Documents\Experiments\Data\Electrochemical\Preannealing\Annealed Pt\02\CC3'
sample = 'LMO Non-Annealed Pt CC3'
df_cv_lmo_na3, capacity_lmo_na3, lith_lmo_na3, delith_lmo_na3, efficiency_lmo_na3 = Ec.Electrochem(path, 90, 0.785, sample)
data = [df_cv_lmo_na3, capacity_lmo_na3, lith_lmo_na3, delith_lmo_na3]
for i in data:
    i['Sample'] = sample

fig, ax = plt.subplots(1, 4, dpi = 100, figsize = (25, 5))
# ax2 = ax[2].twinx()
# sns.scatterplot(data = df_cv_lmo_na2, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'CV', ax = ax[0], edgecolor = None, s = 3)
sns.lineplot(data = lith_lmo_na2, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
sns.lineplot(data = delith_lmo_na2, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', ax = ax[1], hue = 'Cycle', palette = 'BuPu', legend = False)
ax[1].legend(frameon=False)
sns.scatterplot(data = efficiency_lmo_na2[1:], x = 'Cycle' , y = 'Efficiency (%)', ax = ax[3],  c = 'tab:red', s = 200, label = 'Efficiency')

sns.scatterplot(data = capacity_lmo_na2[1:], x = 'Cycle', y = 'Capacity (mAh/cm$^3$)', hue = 'Charge/Discharge', style = 'Charge/Discharge', ax = ax[2], legend = True, markers = ['s', '^' ], s = 100)
# ax[2].legend(bbox_to_anchor=(0.8, 1.1), frameon = False)
# ax2.legend(frameon = False, bbox_to_anchor=(0.5, 1.1), ncols = 2)
plt.suptitle(sample)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0.98, 'LMO Non-Annealed Pt CC3')

# %%
# Put CC1, cc2, cc3 together

sample = 'LMO Non-Annealed Pt 2'

df_charge_na= pd.concat([capacity_lmo_na[capacity_lmo_na['Charge/Discharge'] == 'Charge'], capacity_lmo_na2[capacity_lmo_a1['Charge/Discharge'] == 'Charge'], capacity_lmo_na3[capacity_lmo_a1['Charge/Discharge'] == 'Charge']])
df_charge_na['Cycle'] = np.arange(len(df_charge_na)) + 1
df_discharge_na = pd.concat([capacity_lmo_na[capacity_lmo_na['Charge/Discharge'] == 'Discharge'], capacity_lmo_na2[capacity_lmo_a1['Charge/Discharge'] == 'Discharge'], capacity_lmo_na3[capacity_lmo_a1['Charge/Discharge'] == 'Discharge']])
df_discharge_na['Cycle'] = np.arange(len(df_discharge_na)) + 1
df_na = pd.concat([df_charge_na, df_discharge_na], ignore_index=True)

ef2_na = efficiency_lmo_na2.copy()
ef3_na = efficiency_lmo_na3.copy()
ef2_na['Cycle'] = efficiency_lmo_a1_2['Cycle'] + 5
ef3_na['Cycle'] = efficiency_lmo_a1_3['Cycle'] + 10
eff_na = pd.concat([efficiency_lmo_na, ef2_na, ef3_na])
eff_na['Sample'] = sample

lla2_na = lith_lmo_na2.copy()
lla3_na = lith_lmo_na3.copy()
dla2_na = delith_lmo_na2.copy()
dla3_na = delith_lmo_na3.copy()
lla2['Cycle'] = lith_lmo_na2['Cycle'] + 5
lla3['Cycle'] = lith_lmo_na3['Cycle'] + 10
dla2['Cycle'] = delith_lmo_na2['Cycle'] + 5
dla3['Cycle'] = delith_lmo_na3['Cycle'] + 10

l_na = pd.concat([lith_lmo_na, lla2_na, lla3_na], ignore_index=True)
d_na = pd.concat([delith_lmo_na, dla2_na, dla3_na], ignore_index=True)
l_na['Sample'] = sample
d_na['Sample'] = sample

# ================== PLOT ========================================

fig, ax = plt.subplots( 2, 2, dpi = 200, figsize = (12,10))
sns.scatterplot(data = df_cv_lmo_na, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'CV', ax = ax[0,0], edgecolor = None, s = 3, palette = 'BuPu')
sns.scatterplot(data = df_na, x = 'Cycle', y = 'Capacity (mAh/cm$^3$)', hue = 'Charge/Discharge', style = 'Charge/Discharge', legend = True, markers = ['s', '^' ], s = 200, palette = 'BuPu', ax = ax[1,0])
ax[1,0].set_ylim(400, 600)
sns.lineplot(data = l_na, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', hue = 'Cycle', palette = 'BuPu', legend = False, ax = ax[0,1])
sns.lineplot(data = d_na, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', hue = 'Cycle', palette = 'BuPu', legend = False, ax = ax[0,1])
sns.scatterplot(data = eff_na, x = 'Cycle', y = 'Efficiency (%)', s = 150,  ax = ax[1,1], c = 'tab:purple')
# ax[2].set_title('Efficiency')
ax[1,1].set_ylim(90,100)
plt.suptitle(sample)
# Out:
# Text(0.5, 0.98, 'LMO Non-Annealed Pt 2')

# %%
# ======================= COMPARE =======================================
palette = 'cividis_r'

cv = pd.concat([df_cv_lmo_a1_2, df_cv_lmo_na], ignore_index=True) # df_cv_lmo_ref_na, 

lithiation = pd.concat([l, l_na], ignore_index=True) # , lith_lmo_ref_na

# capacity_all = pd.concat([], ignore_index=True) 

delithiation = pd.concat([ d, d_na], ignore_index=True) #, , delith_lmo_ref_na,

efficiency = pd.concat([ eff, eff_na], ignore_index= True) # , efficiency_lmo_na, efficiency_lmo_ref_na,

# ========== PLOT CV ================================================================================
fig, ax = plt.subplots(1, 3, figsize = (20,5), dpi = 200)
sns.scatterplot(data = cv, x = 'Potential vs Li$^+$/Li (V)', y = 'Current Density ($\mu$A/cm$^2$)', hue = 'Sample', edgecolor = None, s = 3, ax = ax[0], palette=palette)
# ax.legend(bbox_to_anchor=(1,1), frameon = False)
ax[0].set_xlim(3.3, 4.5)

# ========== PLOT lith ================================================================================

sns.scatterplot(data = lithiation, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', hue = 'Sample',  edgecolor = None, s = 3, ax = ax[1], palette=palette)
sns.scatterplot(data = delithiation, x = 'Capacity (mAh/cm$^3$)', y = 'Potential vs Li$^+$/Li (V)', hue = 'Sample', edgecolor = None, s = 3, ax = ax[1], palette=palette, legend = False)

sns.scatterplot(data = efficiency[1:], x = 'Cycle',  y = 'Efficiency (%)', ax = ax[2], hue = 'Sample', style = 'Sample', palette=palette, s = 100)
ax[2].set_ylim(90,100)
# Out:
# (90.0, 100.0)
